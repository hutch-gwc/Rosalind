# %% [markdown]
# <h1>Counting DNA Nucleotides</h1>

# %%
dna = "..."
nts = "ACGT"
base_counts = [ sum(1 for base in dna if base == nt) for nt in nts]

print(" ".join(str(x) for x in base_counts))
# Out:
# 222 241 232 223

# %% [markdown]
# <h1>The Second Nucleic Acid</h1>

# %%
dna = "..."
rna = dna.replace("T","U")
print(rna)
# Out:
# ...

# %% [markdown]
# <h1>Complementing a Strand of DNA</h1>

# %%
dna = "..."

nts = "ACGT"
comp_nts = "TGCA"
complement = dict(zip(nts,comp_nts))

rc = "".join(complement[base] for base in reversed(dna))

print(rc)
# Out:
# ...

# %% [markdown]
# <h1>Introduction to Mendelian Inheritance</h1>

# %%
int_string = "2 2 2"
int_list = int_string.split(" ")
prob_list = [1,.5,0]

for 

print(int_list)
# Out:
# ['2', '2', '2']
